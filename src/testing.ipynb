# %% [markdown]
# # General File Decomposition (to be deleted later)

# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py

# %%
file = np.load('../example_data/ff_thom_cart_i0_r10_nadara.npz')
print(list(file.keys()))
# Out:
# ['mass_msun', 'width', 'frequency', 'adaptive_num_levels', 'I_nu']

# %%
file['adaptive_num_levels']
# Out:
# array([0], dtype=int32)

# %%
file['width']
# Out:
# array([2.])

# %% [markdown]
# # Testing the actual code's ability to read stuff

# %%
import blacklightAthenaProc as bap

# %%
bap.MCSpec('../example_data/',50,1,1000)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-0122c4a65fa7> in <module>
# ----> 1 bap.MCSpec('../example_data/',50,1,1000)
#
# AttributeError: module 'blacklightAthenaProc' has no attribute 'MCSpec'
